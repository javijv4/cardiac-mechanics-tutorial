# %% [markdown]
# # Cardiac Mechanics Tutorial
# This tutorial uses dolfin-x to implement the simulation of a cardiac cycle in a left ventricle.

# %% [markdown]
# Import packages

# %%
import time
import numpy as np
import ufl
from mpi4py import MPI
from petsc4py import PETSc
from dolfinx import io, fem, nls

data_path = '../data/'     # path where files are

# %% [markdown]
# ### Defining the domain
# Read the mesh and boundary information (meshtags)

# %%
# Read mesh
with io.XDMFFile(MPI.COMM_WORLD, data_path + 'mesh.xdmf', "r") as xdmf:
    domain = xdmf.read_mesh(name='Grid')

# Read meshtags (boundary information)
domain.topology.create_connectivity(domain.topology.dim-1, domain.topology.dim)
with io.XDMFFile(MPI.COMM_WORLD, data_path + 'mt.xdmf', "r") as xdmf:
    meshtags = xdmf.read_meshtags(domain, name="Grid")

# %% [markdown]
# The loaded meshtags are shown in the image below and will be necessary to assign boundary conditions to specific surfaces of the mesh.

# %% [markdown]
# ![boundary_patches.png](attachment:boundary_patches.png)

# %% [markdown]
# ### Defining FE spaces and functions of interest
# Define finite element function spaces. In this tutorial, we use a nearly-incompressible simulation, which means we solve for both the displacement and pressure. To do that we first define element types for each field and then a function space is defined that combines both this variables.

# %%
order_u = 1      # polynomial degree for displacement
order_p = 1      # polynomial degree for pressure
Ve = ufl.VectorElement("Lagrange", domain.ufl_cell(), order_u)   # element for displacement: linear continuous lagrange 
Pe = ufl.FiniteElement("Lagrange", domain.ufl_cell(), order_p)   # element for displacement: linear continuous lagrange 

state_space = fem.FunctionSpace(domain, Ve * Pe)

# %% [markdown]
# Now we can define the functions and test functions that are going to be used to define and solve the cardiac mechanics variational problem. Note that we first define a global function/test function (containing displacement and pressure) from the space that we defined before and then we split that space into the displacement and pressure variables.

# %%
# Define functions and test functions
state = fem.Function(state_space)
test_state = ufl.TestFunction(state_space)

u, p = ufl.split(state)       # Splitting the state variable
v, q = ufl.split(test_state)  # Splitting the test variable

# %% [markdown]
# ### Defining microstructure (fibers)
# The fibers for these geometry are provided in the data directory. To use them, we need to define a function space for them and then create functions and assign the values from the data.

# %%
# Defining fiber function space
V_f = fem.VectorFunctionSpace(domain, ('CG', 1))       # space for fibers - continuous linear space

# Defining functions
f0 = fem.Function(V_f)    # In this tutorial fibers are defined in a linear topology
s0 = fem.Function(V_f)
n0 = fem.Function(V_f)

# Reading data
f0_array = np.loadtxt(data_path + 'fiber.txt')
s0_array = np.loadtxt(data_path + 'sheet.txt')
n0_array = np.loadtxt(data_path + 'sheetnormal.txt')

# Assigning values
f0.vector.array = f0_array.flatten()
s0.vector.array = s0_array.flatten()
n0.vector.array = n0_array.flatten()

# %% [markdown]
# Fenics-x calculates quantities and expressions at the quadrature points by interpolating nodal values. One issue that arises with very coarse meshes (as the one used in this tutorial) is that the unitary vectors lose the unitary property when they are interpolated, which causes some issues. For finer meshes, this is not a big problem as the variation between the nodes of an element is small. To avoid issues in this tutorial we precompute the outer product in the fiber direction.

# %%
# Define tensor space
T_f = fem.TensorFunctionSpace(domain, ('CG', 1))       # space for outer product - continuous linear space

# pre compute outer product using nodal values
outer_ff = np.zeros([*f0_array.shape, 3])
for i in range(len(f0_array)):
    outer_ff[i] = np.outer(f0_array[i], f0_array[i])
    
# Assign values to a fenics-x function
ff = fem.Function(T_f)
ff.vector.array = outer_ff.flatten()

# %% [markdown]
# ### Defining the constitutive relationship
# Once that all the functions needed are defined, we can define our constitutive relationship. We first define all the continuum mechanics quantities needed.

# %%
# Kinematics
dim = len(u)
I = ufl.variable(ufl.Identity(dim))
F = ufl.variable(I + ufl.grad(u))         # Deformation gradient
C = ufl.variable(F.T*F)                   # Right Green-Cauchy tensor

# Invariants
J = ufl.variable(ufl.det(F))
Ic = ufl.variable(ufl.tr(C))
Ic_bar = ufl.variable(J**(-2./3.) * Ic)
I4f = ufl.inner(C, ff)

# %% [markdown]
# With this quantities, we define the strain energy density function defining the consitutive relationship. In this tutorial, we will use a modified HO material that only contains the first two terms (isotropic and fiber direction), and that we use an isochoric invariant for the first term.

# %%
# Define HO material law
a = fem.Constant(domain, PETSc.ScalarType(0.4))
b = fem.Constant(domain, PETSc.ScalarType(3.2))
a_f = fem.Constant(domain, PETSc.ScalarType(1.0))
b_f = fem.Constant(domain, PETSc.ScalarType(15.))
Psi_dev = a/(2.*b)*(ufl.exp(b*(Ic_bar-3.)) - 1.) \
    + a_f/(2.*b_f)*(ufl.exp(b_f*(I4f-1.)**2.) - 1.)

# %% [markdown]
# We also need to define the volumetric strain energy density function. Here, we use a nearly incompressible material law.

# %%
k = fem.Constant(domain, PETSc.ScalarType(1e2))
Psi_vol = p * (J - 1) - p**2 / (2*k)

# %% [markdown]
# The first Piola-Kirchhoff stress can be easily computed by differentiating the strain energy density function.

# %%
P_dev = ufl.diff(Psi_dev,F)    # Deviatoric contribution
P_vol = ufl.diff(Psi_vol,F)    # Volumetric contribution

# %% [markdown]
# For the activation of the myocardium, we use an active stress approach. We also add a small transverse contraction that has been shown it helps to get more physiological deformations.

# %%
# Define active stress
f = F*f0       # Define fiber direction
lv_activation = fem.Constant(domain, PETSc.ScalarType(0.))   # value of activation
P_act = lv_activation * (ufl.outer(f,f0) + 0.2 * (I - ufl.outer(f,f0)))

# %% [markdown]
# ### Defining boundary conditions
# For this simple problem, we consider a dirichlet condition (in all directions) in the LV base plus the pressure load in the inner surface of the LV. Note that, since we are using a mixed space to solve for, we need to make sure the BC is applied to the correct space.

# %%
# Boundary conditions
# Fixed base
V, _ = state_space.sub(0).collapse()    # Obtaining the function space of the displacement
dofs = fem.locate_dofs_topological((state_space.sub(0), V), 2, meshtags.find(2))   # Finding the degrees of freedom to be constrained
u_fixed = fem.Function(V)    # Function containing dirichlet condition valeus
u_fixed.x.set(0.0)
bcs = [fem.dirichletbc(u_fixed, dofs, state_space.sub(0))] 

# Endocardial pressure
normal_0 = ufl.FacetNormal(domain)
lv_pressure = fem.Constant(domain, PETSc.ScalarType(0.))   # This contains the lv pressure value. Initialize with 0.
T = -lv_pressure * J * ufl.inv(F).T * normal_0

# %% [markdown]
# ### Defining virtual work principle

# %%
# Define integration domains
ds = ufl.Measure('ds', domain=domain, subdomain_data=meshtags)
dx = ufl.Measure("dx", domain=domain, metadata={'quadrature_degree': 4})

# Virtual work
deltaW_uu = ufl.inner(ufl.grad(v), P_dev)*dx +  ufl.inner(ufl.grad(v), P_act)*dx - ufl.inner(v, T)*ds(3)
deltaW_up = ufl.inner(ufl.grad(v), P_vol)*dx
deltaW_pu = q * (J - 1.) * dx
deltaW_pp = - 1/k * p * q * dx
deltaW = deltaW_uu + deltaW_up + deltaW_pu + deltaW_pp

# %% [markdown]
# ### Setting up the solver

# %%
problem = fem.petsc.NonlinearProblem(deltaW, state, bcs)   # problem to be solve
solver = nls.petsc.NewtonSolver(domain.comm, problem)

# Solver options
solver.atol = 1e-8
solver.rtol = 1e-8
solver.error_on_nonconvergence = False

# %% [markdown]
# ## Cardiac Simulation
# We provide files defining pressure and an activation curve in time defining a cardiac cycle. These files have two columns each. The first one is time and the second the activation values. For easiness of implementation we use the `interp1d` function from `scipy` to define functions that we can evaluate at any time `t`.

# %%
# Read data for activation and pressure
activation = np.loadtxt(data_path + 'activation.txt')
pressure = np.loadtxt(data_path + 'pressure.txt')

# Defining functions
from scipy.interpolate import interp1d
func_act = interp1d(activation[:,0], activation[:,1])
func_pres = interp1d(pressure[:,0], pressure[:,1])

# Defining cycle times
nsteps = 501
times = np.linspace(0, 1, nsteps)[1:]    

import matplotlib.pyplot as plt
plt.figure()
plt.plot(times, func_act(times), label='activation')
plt.plot(times, func_pres(times), label='pressure')
plt.xlabel('Time [s]')
plt.ylabel('Activation/Pressure [kPa]')
plt.legend()

# %% [markdown]
# A cardiac cycle simulation contains two steps, an inflation problem to reach the initial pressure of the cycle and the cycle itself.

# %% [markdown]
# ### Inflation problem

# %%
# Initializing files to save results. Results are saved in the inflation.xdmf file that can be view in paraview.
# If an error appears saying that the HD5F file is already open, make sure to delete any old .xdmf and .h5 files from previous runs.
file = io.XDMFFile(MPI.COMM_WORLD, 'inflation.xdmf', 'w')   
file.write_mesh(domain)

# Incremmentally load the lv using N timesteps
nsteps = 21
pres_values = np.linspace(0, func_pres(0), nsteps+1)[1:]
for i in range(len(pres_values)):
    # Assign pressure value
    lv_pressure.value = pres_values[i]
    
    # Solve
    num_its, converged = solver.solve(state)
    if not converged:   # Check convergence and close file if failure
        file.close()
        assert converged
        
    # Save output
    u, p = state.split()
    file.write_function(u, i)
    
    # Print status
    print(f"Time step {i}, Number of iterations {num_its}, pressure {lv_pressure.value}")
file.close()

# Save inflated state in case we need to restart the next step
inf_state = fem.Function(state_space)
inf_state.vector.array = np.copy(state.vector.array)
# Out:
# Time step 0, Number of iterations 4, pressure 0.05728465007595871
# Time step 1, Number of iterations 4, pressure 0.11456930015191742
# Time step 2, Number of iterations 5, pressure 0.17185395022787614
# Time step 3, Number of iterations 5, pressure 0.22913860030383484
# Time step 4, Number of iterations 4, pressure 0.28642325037979355
# Time step 5, Number of iterations 4, pressure 0.3437079004557523
# Time step 6, Number of iterations 4, pressure 0.40099255053171096
# Time step 7, Number of iterations 4, pressure 0.4582772006076697
# Time step 8, Number of iterations 4, pressure 0.5155618506836284
# Time step 9, Number of iterations 4, pressure 0.5728465007595871
# Time step 10, Number of iterations 4, pressure 0.6301311508355458
# Time step 11, Number of iterations 4, pressure 0.6874158009115046
# Time step 12, Number of iterations 4, pressure 0.7447004509874633
# Time step 13, Number of iterations 4, pressure 0.8019851010634219
# Time step 14, Number of iterations 4, pressure 0.8592697511393806
# Time step 15, Number of iterations 4, pressure 0.9165544012153394
# Time step 16, Number of iterations 4, pressure 0.9738390512912981
# Time step 17, Number of iterations 4, pressure 1.0311237013672567
# Time step 18, Number of iterations 4, pressure 1.0884083514432155
# Time step 19, Number of iterations 4, pressure 1.1456930015191742
# Time step 20, Number of iterations 4, pressure 1.202977651595133

# %% [markdown]
# ### Cardiac Cycle
# **WARNING**: This step takes around 5 min, more or less depending on your computer. The output files are provided in the results folder.

# %%
# Uncomment if you want to restart this step.
# state.vector.array = np.copy(inf_state.vector.array)

# Initializing file to save results
file = io.XDMFFile(MPI.COMM_WORLD, 'cycle.xdmf', 'w') 
file.write_mesh(domain)

start = time.time()  # For timing the simulation
nsteps = 501
times = np.linspace(0, 1, nsteps)[1:]    # We already solved the first step
for i, t in enumerate(times):
    # Set pressure/activation values
    lv_pressure.value = func_pres(t)
    lv_activation.value = func_act(t)

    # Solve
    num_its, converged = solver.solve(u)

    if not converged:  # Check convergence and close file if failure
        file.close()
        assert converged

    # Save output
    u, p = state.split()
    file.write_function(u, i)

    print(f"Time step {i}, Number of iterations {num_its}, pressure {lv_pressure.value}, activation {lv_activation.value}")
file.close()

end = time.time()

print(f"Simulation time {end-start} s")
# Out:
# Time step 0, Number of iterations 4, pressure 1.203658798217899, activation 0.09205960100985
# Time step 1, Number of iterations 5, pressure 1.2040335220676555, activation 0.55128217547625
# Time step 2, Number of iterations 6, pressure 1.2046121076707685, activation 1.37394114489405
# Time step 3, Number of iterations 9, pressure 1.206595431757427, activation 2.5537242835398
# Time step 4, Number of iterations 9, pressure 1.2143398963171526, activation 4.08181950476835
# Time step 5, Number of iterations 7, pressure 1.2365235157571695, activation 5.947023986080651
# Time step 6, Number of iterations 6, pressure 1.2729798772168495, activation 8.135880383892301
# Time step 7, Number of iterations 5, pressure 1.33251562948175, activation 10.63283783081235
# Time step 8, Number of iterations 5, pressure 1.4224186816991287, activation 13.392693467905657
# Time step 9, Number of iterations 4, pressure 1.5504583812782606, activation 16.15366316313915
# Time step 10, Number of iterations 4, pressure 1.7241880112099623, activation 18.860230847908653
# Time step 11, Number of iterations 4, pressure 1.949957653459005, activation 21.5134684567407
# Time step 12, Number of iterations 4, pressure 2.2321553982142546, activation 24.114426802816652
# Time step 13, Number of iterations 4, pressure 2.5726553181566856, activation 26.664135994146896
# Time step 14, Number of iterations 4, pressure 2.9697389531584832, activation 29.16360584154435
# Time step 15, Number of iterations 4, pressure 3.417210784176629, activation 31.61382625855995
# Time step 251, Number of iterations 4, pressure 2.192968045642926, activation 13.12220022355905
# Time step 252, Number of iterations 4, pressure 2.072040154776229, activation 12.3689322495609
# Time step 253, Number of iterations 4, pressure 1.9573983708045946, activation 11.658904938788549
# Time step 254, Number of iterations 4, pressure 1.8487278889126224, activation 10.98963610028145
# Time step 255, Number of iterations 4, pressure 1.7457279071738847, activation 10.358786030994
# Time step 256, Number of iterations 4, pressure 1.6481115276168439, activation 9.7641493364067
# Time step 257, Number of iterations 4, pressure 1.5556054693188976, activation 9.20364722066805
# Time step 258, Number of iterations 4, pressure 1.4679496664868705, activation 8.67532021931205
# Time step 259, Number of iterations 4, pressure 1.3848967904092533, activation 8.1773213491488
# Time step 260, Number of iterations 4, pressure 1.3062117225396488, activation 7.7079096513798
# Time step 261, Number of iterations 4, pressure 1.2438319925450114, activation 7.2654441053631
# Time step 262, Number of iterations 4, pressure 1.2206179450948935, activation 6.8483778917553
# Time step 263, Number of iterations 4, pressure 1.194186891099028, activation 6.455252984970601
# Time step 264, Number of iterations 4, pressure 1.1702175431852455, activation 6.08469505605675
# Time step 265, Number of iterations 4, pressure 1.148691032806091, activation 5.735408668165499
# Time step 266, Number of iterations 4, pressure 1.1286229219513986, activation 5.40617274782295
# Time step 267, Number of iterations 4, pressure 1.10945373084603, activation 5.0958363161683495
# Time step 268, Number of iterations 4, pressure 1.0909916232089005, activation 4.8033144652354505
# Time step 269, Number of iterations 4, pressure 1.0731627257198855, activation 4.52758456521405
# Time step 270, Number of iterations 4, pressure 1.0558945070421575, activation 4.267682689427851
# Time step 271, Number of iterations 4, pressure 1.039103541480341, activation 4.0227002445355495
# Time step 272, Number of iterations 4, pressure 1.0227111562718625, activation 3.7917807941706
# Time step 273, Number of iterations 4, pressure 1.0066520449370069, activation 3.5741170649172
# Time step 274, Number of iterations 4, pressure 0.9908741184111612, activation 3.3689481241559998
# Time step 275, Number of iterations 4, pressure 0.9753359439561148, activation 3.1755567199134003
# Time step 276, Number of iterations 4, pressure 0.9600047629600637, activation 2.9932667734125
# Time step 277, Number of iterations 4, pressure 0.9448553546592867, activation 2.82144101556465
# Time step 278, Number of iterations 4, pressure 0.9298691573606883, activation 2.65947875913345
# Time step 279, Number of iterations 4, pressure 0.9150332769466468, activation 2.50681379878725
# Time step 280, Number of iterations 4, pressure 0.9003396748517101, activation 2.3629124316968997
# Time step 281, Number of iterations 4, pressure 0.8857847583743261, activation 2.2272715917587926
# Time step 282, Number of iterations 4, pressure 0.8713693521073484, activation 2.099417090921693
# Time step 283, Number of iterations 4, pressure 0.8570982147393532, activation 1.9789019614682937
# Time step 284, Number of iterations 4, pressure 0.8429789592155107, activation 1.865304893456694
# Time step 285, Number of iterations 4, pressure 0.8290209629966563, activation 1.758228761859444
# Time step 286, Number of iterations 4, pressure 0.8152341443307471, activation 1.6572992382500948
# Time step 287, Number of iterations 4, pressure 0.8016284924317993, activation 1.562163482185045
# Time step 288, Number of iterations 4, pressure 0.7882145788022626, activation 1.4724889077057
# Time step 289, Number of iterations 4, pressure 0.7750037722363267, activation 1.3879620206482501
# Time step 290, Number of iterations 4, pressure 0.762008033460746, activation 1.3082873226960001
# Time step 291, Number of iterations 4, pressure 0.7492398872671429, activation 1.2331862783448
# Time step 292, Number of iterations 4, pressure 0.7367123033489913, activation 1.1623963411677
# Time step 293, Number of iterations 4, pressure 0.7244377317184191, activation 1.0956700359768
# Time step 294, Number of iterations 4, pressure 0.7124266958788179, activation 1.0327740936721501
# Time step 295, Number of iterations 4, pressure 0.7006877246657744, activation 0.9734886357546
# Time step 296, Number of iterations 4, pressure 0.6892287632519876, activation 0.9176064056505
# Time step 297, Number of iterations 3, pressure 0.678058534062736, activation 0.86493204416115
# Time step 298, Number of iterations 3, pressure 0.6671867836221047, activation 0.815281406505
# Time step 299, Number of iterations 3, pressure 0.6566240355367566, activation 0.76848091856445
# Time step 300, Number of iterations 3, pressure 0.6463812274511241, activation 0.7243669700862
# Time step 301, Number of iterations 3, pressure 0.6364691587639116, activation 0.6827853427149
# Time step 302, Number of iterations 3, pressure 0.6268975562316783, activation 0.64359067085955
# Time step 303, Number of iterations 3, pressure 0.6176743753017353, activation 0.6066459335088
# Time step 304, Number of iterations 3, pressure 0.6088054707120164, activation 0.57182197521795
# Time step 305, Number of iterations 3, pressure 0.6002949828137581, activation 0.53899705459335
# Time step 306, Number of iterations 3, pressure 0.5921462014215598, activation 0.50805641869485
# Time step 307, Number of iterations 3, pressure 0.5843618543398524, activation 0.47889190187084996
# Time step 308, Number of iterations 3, pressure 0.5769440235682702, activation 0.45140154762075
# Time step 309, Number of iterations 3, pressure 0.5698940475843993, activation 0.4254892521639
# Time step 310, Number of iterations 3, pressure 0.563212071933202, activation 0.40106442847004997
# Time step 311, Number of iterations 3, pressure 0.5568966882598891, activation 0.378041689575
# Time step 312, Number of iterations 3, pressure 0.5509450018430164, activation 0.35634055007535004
# Time step 313, Number of iterations 3, pressure 0.5453528944120426, activation 0.33588514475955
# Time step 314, Number of iterations 3, pressure 0.5401152050645294, activation 0.31660396338915
# Time step 315, Number of iterations 3, pressure 0.5352255612273195, activation 0.2984296007061
# Time step 316, Number of iterations 3, pressure 0.5306761366594736, activation 0.2812985207901
# Time step 317, Number of iterations 3, pressure 0.5264576794203368, activation 0.26515083494205
# Time step 318, Number of iterations 3, pressure 0.5225599083932316, activation 0.24993009231975
# Time step 319, Number of iterations 3, pressure 0.5189720798966677, activation 0.2355830825901
# Time step 320, Number of iterations 3, pressure 0.5156832867361272, activation 0.2220596499105
# Time step 321, Number of iterations 3, pressure 0.5126824503057263, activation 0.20931251758935002
# Time step 322, Number of iterations 3, pressure 0.5099582315380475, activation 0.1972971228102
# Time step 323, Number of iterations 3, pressure 0.5074989581423678, activation 0.18597146084475
# Time step 324, Number of iterations 3, pressure 0.5052925863125857, activation 0.1752959382078
# Time step 325, Number of iterations 3, pressure 0.5033268020262167, activation 0.1652332342425
# Time step 326, Number of iterations 3, pressure 0.5015893344430262, activation 0.1557481706499
# Time step 440, Number of iterations 3, pressure 0.7162579920645021, activation 0.00018430440764999998
# Time step 441, Number of iterations 3, pressure 0.7220304042180725, activation 0.00017372458065
# Time step 442, Number of iterations 3, pressure 0.7281919680030421, activation 0.00016375207905
# Time step 443, Number of iterations 3, pressure 0.7347419677189369, activation 0.00015435203985
# Time step 444, Number of iterations 3, pressure 0.7416776515286094, activation 0.00014549160135000002
# Time step 445, Number of iterations 3, pressure 0.7489943078921508, activation 0.00013713978825
# Time step 446, Number of iterations 3, pressure 0.7566853390479934, activation 0.00012926740335000001
# Time step 447, Number of iterations 3, pressure 0.7647423323222181, activation 0.00012184692555
# Time step 448, Number of iterations 3, pressure 0.7731551300772805, activation 0.00011485241355
# Time step 449, Number of iterations 3, pressure 0.7819118993610268, activation 0.00010825941524999999
# Time step 450, Number of iterations 3, pressure 0.7909992018750118, activation 0.00010204488195
# Time step 451, Number of iterations 3, pressure 0.8004020655051738, activation 9.618708825e-05
# Time step 452, Number of iterations 3, pressure 0.8101040585619497, activation 9.066555585e-05
# Time step 453, Number of iterations 3, pressure 0.8200873674971783, activation 8.546098215e-05
# Time step 454, Number of iterations 3, pressure 0.8303328791527204, activation 8.055517215e-05
# Time step 455, Number of iterations 3, pressure 0.8408202685817989, activation 7.593097575e-05
# Time step 456, Number of iterations 3, pressure 0.8515280931227559, activation 7.1572227e-05
# Time step 457, Number of iterations 3, pressure 0.8624338933078911, activation 6.746368845e-05
# Time step 458, Number of iterations 3, pressure 0.8735143009105977, activation 6.35909967e-05
# Time step 459, Number of iterations 3, pressure 0.884745154104019, activation 5.994061335e-05
# Time step 460, Number of iterations 3, pressure 0.8961016193616316, activation 5.6499776999999994e-05
# Time step 461, Number of iterations 3, pressure 0.9075583193451094, activation 5.325645855e-05
# Time step 462, Number of iterations 3, pressure 0.9190894656177059, activation 5.0199320100000005e-05
# Time step 463, Number of iterations 3, pressure 0.9306689947359748, activation 4.7317673700000003e-05
# Time step 464, Number of iterations 3, pressure 0.9422707059217885, activation 4.4601445650000005e-05
# Time step 465, Number of iterations 3, pressure 0.9538683983516888, activation 4.20411402e-05
# Time step 466, Number of iterations 3, pressure 0.9654360059279853, activation 3.962780685e-05
# Time step 467, Number of iterations 3, pressure 0.9769477274758065, activation 3.7353008549999995e-05
# Time step 468, Number of iterations 3, pressure 0.9883781503327084, activation 3.520879304999988e-05
# Time step 469, Number of iterations 3, pressure 0.9997023655677701, activation 3.318766424999989e-05
# Time step 470, Number of iterations 3, pressure 1.0108960733463082, activation 3.1282556549999896e-05
# Time step 471, Number of iterations 3, pressure 1.021935677334493, activation 2.9486809949999904e-05
# Time step 472, Number of iterations 3, pressure 1.032798367449561, activation 2.7794146349999907e-05
# Time step 473, Number of iterations 3, pressure 1.0434621906840633, activation 2.6198648699999915e-05
# Time step 474, Number of iterations 3, pressure 1.0539061101367875, activation 2.469473909999992e-05
# Time step 475, Number of iterations 3, pressure 1.0641100527469685, activation 2.3277160049999927e-05
# Time step 476, Number of iterations 3, pressure 1.0740549465138447, activation 2.194095584999993e-05
# Time step 477, Number of iterations 3, pressure 1.0837227482145202, activation 2.068145519999993e-05
# Time step 478, Number of iterations 3, pressure 1.0930964627611843, activation 1.9494254999999937e-05
# Time step 479, Number of iterations 3, pressure 1.1021601553805667, activation 1.837520505e-05
# Time step 480, Number of iterations 3, pressure 1.110898957782923, activation 1.73203932e-05
# Time step 481, Number of iterations 3, pressure 1.1192990693901332, activation 1.63261317e-05
# Time step 482, Number of iterations 3, pressure 1.1273477545538308, activation 1.5388944900000003e-05
# Time step 483, Number of iterations 3, pressure 1.1350333365220444, activation 1.45055565e-05
# Time step 484, Number of iterations 3, pressure 1.1423451887261202, activation 1.3672878299999999e-05
# Time step 485, Number of iterations 3, pressure 1.1492737237742383, activation 1.28879991e-05
# Time step 486, Number of iterations 3, pressure 1.15581038036826, activation 1.2148175249999999e-05
# Time step 487, Number of iterations 3, pressure 1.1619476082176992, activation 1.14508203e-05
# Time step 488, Number of iterations 3, pressure 1.1676788509167288, activation 1.07934963e-05
# Time step 489, Number of iterations 3, pressure 1.1729985266796474, activation 1.017390555e-05
# Time step 490, Number of iterations 3, pressure 1.1779020068175714, activation 9.58988175e-06
# Time step 491, Number of iterations 3, pressure 1.1823855917936432, activation 9.039383250000001e-06
# Time step 492, Number of iterations 3, pressure 1.1864464848543208, activation 8.5204857e-06
# Time step 493, Number of iterations 3, pressure 1.1900827631521371, activation 8.031374999999999e-06
# Time step 494, Number of iterations 3, pressure 1.1932933464924496, activation 7.57034115e-06
# Time step 495, Number of iterations 3, pressure 1.196077963864758, activation 7.1357727e-06
# ...
# Time step 336, Number of iterations 3, pressure 0.49452828364787943, activation 0.08623398584775001
# Time step 337, Number of iterations 3, pressure 0.49466077947773507, activation 0.0812838022884
# Time step 338, Number of iterations 3, pressure 0.4949156368310993, activation 0.0766177795158
# Time step 339, Number of iterations 3, pressure 0.49528694226318715, activation 0.0722196055386
# Time step 340, Number of iterations 3, pressure 0.495769070655613, activation 0.06807390473985
# Time step 341, Number of iterations 3, pressure 0.49635666930801514, activation 0.0641661841266
# Time step 342, Number of iterations 3, pressure 0.49704461438720915, activation 0.060482782662449996
# Time step 343, Number of iterations 3, pressure 0.49782804316734564, activation 0.05701082351069981
# Time step 344, Number of iterations 3, pressure 0.4987024318774392, activation 0.05373816901754983
# Time step 345, Number of iterations 3, pressure 0.4996635896762927, activation 0.050653378280249836
# Time step 346, Number of iterations 3, pressure 0.5007076094156556, activation 0.04774566715079984
# Time step 347, Number of iterations 3, pressure 0.5018307921139776, activation 0.045004870535099856
# Time step 348, Number of iterations 3, pressure 0.5030295948414857, activation 0.042421406857499865
# Time step 349, Number of iterations 3, pressure 0.5043005899389319, activation 0.039986244563549864
# Time step 350, Number of iterations 3, pressure 0.505640445127941, activation 0.03769087054724987
# Time step 351, Number of iterations 3, pressure 0.507045937184646, activation 0.03552726038955
# Time step 352, Number of iterations 3, pressure 0.5085139758565049, activation 0.03348785030595
# Time step 429, Number of iterations 3, pressure 0.6734296026392796, activation 0.00035314630379999995
# Time step 430, Number of iterations 3, pressure 0.6785438995285449, activation 0.0003328742613
# Time step 431, Number of iterations 3, pressure 0.6808161612324116, activation 0.000313765917
# Time step 432, Number of iterations 3, pressure 0.6834337350032479, activation 0.00029575446975
# Time step 433, Number of iterations 3, pressure 0.6863409408432916, activation 0.00027877695330000003
# Time step 434, Number of iterations 3, pressure 0.6895581367138331, activation 0.00026277401565
# Time step 435, Number of iterations 3, pressure 0.6931052603871197, activation 0.0002476897122
# Time step 436, Number of iterations 3, pressure 0.6969983003080362, activation 0.00023347130955000001
# Time step 437, Number of iterations 3, pressure 0.7012505679713753, activation 0.0002200691013
# Time step 438, Number of iterations 3, pressure 0.705872819908905, activation 0.00020743623449999998
# Time step 439, Number of iterations 3, pressure 0.7108733309999316, activation 0.00019552854615
# Time step 440, Number of iterations 3, pressure 0.7162579920645021, activation 0.00018430440764999998
# Time step 441, Number of iterations 3, pressure 0.7220304042180725, activation 0.00017372458065
# Time step 442, Number of iterations 3, pressure 0.7281919680030421, activation 0.00016375207905
# Time step 443, Number of iterations 3, pressure 0.7347419677189369, activation 0.00015435203985
# Time step 444, Number of iterations 3, pressure 0.7416776515286094, activation 0.00014549160135000002
# Time step 445, Number of iterations 3, pressure 0.7489943078921508, activation 0.00013713978825
# Time step 446, Number of iterations 3, pressure 0.7566853390479934, activation 0.00012926740335000001
# Time step 447, Number of iterations 3, pressure 0.7647423323222181, activation 0.00012184692555
# Time step 448, Number of iterations 3, pressure 0.7731551300772805, activation 0.00011485241355
# Time step 449, Number of iterations 3, pressure 0.7819118993610268, activation 0.00010825941524999999
# Time step 450, Number of iterations 3, pressure 0.7909992018750118, activation 0.00010204488195
# Time step 451, Number of iterations 3, pressure 0.8004020655051738, activation 9.618708825e-05
# Time step 452, Number of iterations 3, pressure 0.8101040585619497, activation 9.066555585e-05
# Time step 453, Number of iterations 3, pressure 0.8200873674971783, activation 8.546098215e-05
# Time step 454, Number of iterations 3, pressure 0.8303328791527204, activation 8.055517215e-05
# Time step 455, Number of iterations 3, pressure 0.8408202685817989, activation 7.593097575e-05
# Time step 456, Number of iterations 3, pressure 0.8515280931227559, activation 7.1572227e-05
# Time step 457, Number of iterations 3, pressure 0.8624338933078911, activation 6.746368845e-05
# Time step 458, Number of iterations 3, pressure 0.8735143009105977, activation 6.35909967e-05
# Time step 459, Number of iterations 3, pressure 0.884745154104019, activation 5.994061335e-05
# Time step 460, Number of iterations 3, pressure 0.8961016193616316, activation 5.6499776999999994e-05
# Time step 461, Number of iterations 3, pressure 0.9075583193451094, activation 5.325645855e-05
# Time step 462, Number of iterations 3, pressure 0.9190894656177059, activation 5.0199320100000005e-05
# Time step 463, Number of iterations 3, pressure 0.9306689947359748, activation 4.7317673700000003e-05
# Time step 464, Number of iterations 3, pressure 0.9422707059217885, activation 4.4601445650000005e-05
# Time step 465, Number of iterations 3, pressure 0.9538683983516888, activation 4.20411402e-05
# Time step 466, Number of iterations 3, pressure 0.9654360059279853, activation 3.962780685e-05
# Time step 467, Number of iterations 3, pressure 0.9769477274758065, activation 3.7353008549999995e-05
# Time step 468, Number of iterations 3, pressure 0.9883781503327084, activation 3.520879304999988e-05
# Time step 469, Number of iterations 3, pressure 0.9997023655677701, activation 3.318766424999989e-05
# Time step 470, Number of iterations 3, pressure 1.0108960733463082, activation 3.1282556549999896e-05
# Time step 471, Number of iterations 3, pressure 1.021935677334493, activation 2.9486809949999904e-05
# Time step 472, Number of iterations 3, pressure 1.032798367449561, activation 2.7794146349999907e-05
# Time step 473, Number of iterations 3, pressure 1.0434621906840633, activation 2.6198648699999915e-05
# Time step 474, Number of iterations 3, pressure 1.0539061101367875, activation 2.469473909999992e-05
# Time step 475, Number of iterations 3, pressure 1.0641100527469685, activation 2.3277160049999927e-05
# Time step 476, Number of iterations 3, pressure 1.0740549465138447, activation 2.194095584999993e-05
# Time step 477, Number of iterations 3, pressure 1.0837227482145202, activation 2.068145519999993e-05
# Time step 478, Number of iterations 3, pressure 1.0930964627611843, activation 1.9494254999999937e-05
# Time step 479, Number of iterations 3, pressure 1.1021601553805667, activation 1.837520505e-05
# Time step 480, Number of iterations 3, pressure 1.110898957782923, activation 1.73203932e-05
# Time step 481, Number of iterations 3, pressure 1.1192990693901332, activation 1.63261317e-05
# Time step 482, Number of iterations 3, pressure 1.1273477545538308, activation 1.5388944900000003e-05
# Time step 483, Number of iterations 3, pressure 1.1350333365220444, activation 1.45055565e-05
# Time step 484, Number of iterations 3, pressure 1.1423451887261202, activation 1.3672878299999999e-05
# Time step 485, Number of iterations 3, pressure 1.1492737237742383, activation 1.28879991e-05
# Time step 486, Number of iterations 3, pressure 1.15581038036826, activation 1.2148175249999999e-05
# Time step 487, Number of iterations 3, pressure 1.1619476082176992, activation 1.14508203e-05
# Time step 488, Number of iterations 3, pressure 1.1676788509167288, activation 1.07934963e-05
# Time step 489, Number of iterations 3, pressure 1.1729985266796474, activation 1.017390555e-05
# Time step 490, Number of iterations 3, pressure 1.1779020068175714, activation 9.58988175e-06
# Time step 491, Number of iterations 3, pressure 1.1823855917936432, activation 9.039383250000001e-06
# Time step 492, Number of iterations 3, pressure 1.1864464848543208, activation 8.5204857e-06
# Time step 493, Number of iterations 3, pressure 1.1900827631521371, activation 8.031374999999999e-06
# Time step 494, Number of iterations 3, pressure 1.1932933464924496, activation 7.57034115e-06
# Time step 495, Number of iterations 3, pressure 1.196077963864758, activation 7.1357727e-06
# Time step 496, Number of iterations 3, pressure 1.1984371180365252, activation 6.72615015e-06
# Time step 497, Number of iterations 3, pressure 1.2003720485722078, activation 6.3400415999999996e-06
# Time step 498, Number of iterations 2, pressure 1.2018846937118823, activation 5.9760972e-06
# Time step 499, Number of iterations 2, pressure 1.202977651595133, activation 5.6330448e-06
# Simulation time 140.293301820755 s

# %%
# Cleaning up
f0.vector.destroy()
s0.vector.destroy()
n0.vector.destroy()
u.vector.destroy()
